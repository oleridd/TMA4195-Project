# %% [markdown]
# ### Testing the FDM for solving the 2D diffusion equation

# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append("../../")

from Numeric.DiffusionFDM2D import DiffusionFDM2D

# %%
system = DiffusionFDM2D(max_timestep=100, S=1)
system.solve()

# %%
system.solution
# Out:
# array([[[ 1.42857143e-01,  1.42857143e-01,  1.42857143e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 1.42857143e-01,  1.42857143e-01,  1.42857143e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 1.42857143e-01,  1.42857143e-01,  1.42857143e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.85714286e-01,  2.85714286e-01,  2.85714286e-01, ...,
# ...
