# %% [markdown]
# ## Testing uniform random walk

# %%
import sys
sys.path.append("../../")

from scipy.stats import lognorm
import matplotlib.pyplot as plt
import numpy as np

from Numeric.RandomWalkSim import RandomWalk

# %%
step = lognorm(.01, -0.5)

# %%
sample_size=10000

plt.hist(
    np.sort(step.rvs(size=sample_size))[:int(0.995*sample_size)],
    bins=100,
    density=True,
    histtype='stepfilled',
    );

# %%
RW = RandomWalk(N=1000, Nstep=100, step=step, D=2)

# %%
RW.plot2D(timestep=1)

# %%
RW.plot2D()

# %% [markdown]
# ## Attempting simulation with layers

# %%
from Numeric.NeuroRandomWalk import NeuroRandomWalk

NRW = NeuroRandomWalk(N=1000, Nstep=100, step=step, Nlayers=10, layer_distr={"type": "simple", "params": 0.1})

# %%
print(NRW.layers[-1])
# Out:
# [0 1 7 4 3 3 2 2 3 3 3 0 3 0 9 8 2 1 2 0 3 5 4 1 0 1 0 5 1 8 4 2 2 7 7 1 3
#  0 3 7 5 4 3 7 7 6 0 4 0 4 6 7 0 5 4 8 4 3 1 0 2 7 2 6 3 2 3 6 8 9 6 8 2 3
#  3 5 4 3 6 3 6 7 2 1 6 0 3 3 1 6 4 8 5 2 5 5 4 3 5 7 3 5 1 2 8 1 1 2 0 0 6
#  5 2 2 0 1 6 9 0 0 3 6 0 6 0 7 0 2 0 5 3 1 3 8 7 1 2 0 1 0 0 4 5 4 3 1 2 7
#  0 3 2 6 1 4 1 7 5 3 1 0 7 0 3 4 1 1 9 1 7 0 0 4 0 8 1 0 5 2 4 7 1 2 3 0 0
#  5 1 4 6 9 6 1 1 3 0 6 1 2 9 1 4 0 6 2 3 0 4 9 3 1 9 1 2 8 2 0 1 0 2 0 9 4
#  0 4 0 0 0 6 5 8 2 7 2 0 3 8 1 3 0 9 5 5 3 0 1 2 2 2 5 0 3 1 0 3 2 6 5 1 1
#  4 3 0 4 4 0 1 1 2 1 0 0 2 9 0 0 2 3 3 4 5 1 5 7 8 0 3 6 6 1 7 3 7 7 5 1 5
#  1 0 1 3 1 0 3 1 7 6 4 2 5 2 5 2 0 2 7 3 1 7 5 9 3 1 2 3 1 1 0 0 2 6 7 1 8
#  4 5 6 0 2 1 7 2 2 2 6 8 4 7 1 4 2 0 1 0 9 2 1 0 2 9 1 3 7 2 2 0 4 2 9 5 3
#  0 0 3 7 6 7 1 6 0 6 9 0 7 2 0 6 2 4 8 6 1 0 1 5 2 0 4 3 3 5 6 3 3 0 4 2 0
